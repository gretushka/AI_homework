# %%
from pprint import pprint
from bs4 import BeautifulSoup as bs
import requests
from time import sleep

url = 'https://tomsk.hh.ru/search/vacancy'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36',
}
params = {
    'text': vacancy,
}
# Out:
# Input  the vacancy your intereted in:/nweb

# %%
vacancy = input('Input  the vacancy your intereted in:\n')
# Out:
# Input  the vacancy your intereted in:
# analysis

# %%
def parse_vacancy_hh(dom_vacancy):
  sleep(0.1)
  vacancy_name = dom_vacancy.find('a').text

  vacancy_salary = dom_vacancy.find('span', {'class', 'bloko-header-section-3'})
  if vacancy_salary:
    vacancy_salary = vacancy_salary.text
    min_salary, max_salary, currency_salary = clean_salary(vacancy_salary)
  else:
    min_salary, max_salary, currency_salary = None, None, None

  vacancy_link = dom_vacancy.find('a')['href']
  
  return {
      'vacancy_name': vacancy_name,
      'vacancy_salary': vacancy_salary,
      'min_salary': min_salary,
      'max_salary': max_salary,
      'currency_salary': currency_salary,
      'vacancy_link': vacancy_link,
      'vacancy_source': 'hh.ru',
  }

# %%
def clean_salary(vacancy_salary_text, min_salary=None, max_salary=None, currency_salary=None):
  list_salary = vacancy_salary_text.replace('\u202f', '').split()
  for i in range(len(list_salary) - 1):
    if list_salary[i] == 'от':
      min_salary = int(list_salary[i + 1])
    elif list_salary[i] == 'до':
      max_salary = int(list_salary[i + 1])
    elif list_salary[i] == '–':
      min_salary = int(list_salary[i - 1])
      max_salary = int(list_salary[i + 1])
  currency_salary = list_salary[-1]

  return min_salary, max_salary, currency_salary

# %%
res = []
params = {
    'text': vacancy,
}
while True:
    response = requests.get(url, headers=headers, params=params)
    if response.status_code != 200:
        break
    print(response.url)
    dom = bs(response.content, 'html.parser')
    vacancies = dom.find_all('div', {'class': 'vacancy-serp-item__layout'})
    for vacancy in vacancies:
      res.append(parse_vacancy_hh(vacancy))
    if 'page' in params.keys():
        params['page'] += 1
    else:
        params['page'] = 1

     

pprint(res)
# Out:
# https://tomsk.hh.ru/search/vacancy?text=analysis
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=1
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=2
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=3
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=4
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=5
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=6
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=7
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=8
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=9
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=10
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=11
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=12
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=13
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=14
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=15
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=16
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=17
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=18
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=19
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=20
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=21
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=22
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=23
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=24
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=25
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=26
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=27
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=28
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=29
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=30
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=31
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=32
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=33
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=34
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=35
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=36
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=37
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=38
# https://tomsk.hh.ru/search/vacancy?text=analysis&page=39
# [{'currency_salary': 'руб.',
#   'max_salary': None,
#   'min_salary': 126000,
#   'vacancy_link': 'https://adsrv.hh.ru/click?b=366313&c=45&meta=c2b9-x31MuVHoHLCow21uGZzIgJbN5Ik6YkBTS3i9Nuo8A4vHIV2y8rJe4C2RbWrbsg03IKt9AxUSactAIL6Ujgt0VUGpY7h1HFZyoV4nXM6u5kQ98JmqhfjVhhfNTjFuima53m6WMGKdGT7zueFJHWzw0KMR05Kprp5fe-hJnQmQ-evCTlYmpeL8zLk-ClNKruThypeQnNTeqDAKoRxYA%3D%3D&place=35&clickType=link_to_vacancy',
#   'vacancy_name': 'Management Trainee - Finance',
#   'vacancy_salary': 'от 126\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': None,
#   'min_salary': 126000,
#   'vacancy_link': 'https://adsrv.hh.ru/click?b=366310&c=45&meta=sNlvr7M5b84RT9jh79M9dwouL-kDhz3YGmj5KM7i8gyK-Tv6OeYGTwh2k8_k9Kd83c2PcZws93HwkOcF7OnGhrHA7kpJvQ0Qd6az-RGBNRgi-BYcz2HDZplxMDtM9jtzI1RrzQRPEiKRZBlQ009xBuqV9KJ5TRC054y-6wI-Lz49_fHrz3U_CbW3FUJSSsrSymR9ipKSAZiMnKwtTN-Tfg%3D%3D&place=36&clickType=link_to_vacancy',
#   'vacancy_name': 'Management Trainee - Consumer Marketing',
#   'vacancy_salary': 'от 126\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76979159?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Systems Analyst (Middle)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': 250000,
#   'min_salary': 180000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77005754?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Financial Specialist (Controlling)',
#   'vacancy_salary': '180\u202f000 – 250\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/72920605?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Специалист по углубленной аналитике данных (Data scientist)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'KZT',
#   'max_salary': 500000,
#   'min_salary': 200000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77052200?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Real estate strategy consultant/Project Manager',
#   'vacancy_salary': '200\u202f000 – 500\u202f000 KZT',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76969005?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Quality Lead',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/71653349?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Финансовый аналитик (Middle/Senior/Lead)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76936936?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Analyst/Expert',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76118580?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Junior Analyst / Analyst (Vladivostok)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'EUR',
#   'max_salary': 8000,
#   'min_salary': 5000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76506452?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Quantitative Analyst',
#   'vacancy_salary': '5\u202f000 – 8\u202f000 EUR',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76471424?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Information Sales Analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'USD',
#   'max_salary': 5000,
#   'min_salary': 2500,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76980765?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Business Analyst',
#   'vacancy_salary': '2\u202f500 – 5\u202f000 USD',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77010786?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Organization Specialist (Data Analyst)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76217620?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Senior Analyst / Head of Analytical department',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76595423?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Buy-side analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/75863011?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Market Analyst \\ Researcher',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76928376?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Finance analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'USD',
#   'max_salary': 3500,
#   'min_salary': 2500,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76866293?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Data Analyst (middle/senior)',
#   'vacancy_salary': '2\u202f500 – 3\u202f500 USD',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': 300000,
#   'min_salary': 250000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76450599?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Associate',
#   'vacancy_salary': '250\u202f000 – 300\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77116236?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'PowerBI аналитик (data engineer)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77001681?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'HR Advisor',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77085501?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Business analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76254806?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Аналитик',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': 30000,
#   'min_salary': 30000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76866122?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Junior Business Analyst',
#   'vacancy_salary': '30\u202f000 – 30\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76949549?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Инженер-разработчик (анализ поведения коллектора) '
#                   '(Reservoir Performances Analysis Engineer)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': 120000,
#   'min_salary': 80000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77024983?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Аналитик данных / Data Analyst',
#   'vacancy_salary': '80\u202f000 – 120\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'USD',
#   'max_salary': 6000,
#   'min_salary': 2500,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76735583?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Data analyst',
#   'vacancy_salary': '2\u202f500 – 6\u202f000 USD',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76409285?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Junior Ship Broker',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76862187?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Database & BI reporting Manager',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'USD',
#   'max_salary': 1300,
#   'min_salary': 1000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76963821?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Product Researcher / Finance Analyst',
#   'vacancy_salary': '1\u202f000 – 1\u202f300 USD',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76975853?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Старший аналитик по управлению товарными запасами',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76863946?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Merchandise planner & analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76402531?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Бизнес-аналитик (PM team)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/74340914?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Market Manager (Materials & Energy)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'USD',
#   'max_salary': 6000,
#   'min_salary': 4000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76730425?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Product Owner (gambling)',
#   'vacancy_salary': '4\u202f000 – 6\u202f000 USD',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77090847?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Marketing analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': 140000,
#   'min_salary': 120000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76321679?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Старший бизнес-аналитик',
#   'vacancy_salary': '120\u202f000 – 140\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76982950?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Business Analyst (Cyprus)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77094646?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Финансовый аналитик',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77066896?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Аналитик в Отдел скоринга',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'USD',
#   'max_salary': None,
#   'min_salary': 3000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76697541?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'VoC Business Analyst (Customer Experience Analytics Team)',
#   'vacancy_salary': 'от 3\u202f000 USD',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': 120000,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76151297?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Middle Data Analyst',
#   'vacancy_salary': 'до 120\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/68480223?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Business analyst (remote)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76915503?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Product Analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76775156?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Руководитель отдела финансового планирования, анализа и '
#                   'моделирования',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/70701001?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Team Lead Fraud Analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76567296?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Financial Manager',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76841641?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Дата-аналитик',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': None,
#   'min_salary': 150000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77000923?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Финансовый аналитик',
#   'vacancy_salary': 'от 150\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76660547?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Маркетинговый аналитик',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': 350000,
#   'min_salary': 300000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77001755?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Product owner',
#   'vacancy_salary': '300\u202f000 – 350\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76969007?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Senior EDA EM/IR Analysis EDA Software Engineer and '
#                   'Architect',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77111607?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'PSM Manager (Product Strategic Management)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': 200000,
#   'min_salary': 170000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/69885860?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'IT-аналитик (удаленно, с территории РФ)',
#   'vacancy_salary': '170\u202f000 – 200\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/73527795?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Team Lead Fraud Analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76704863?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Fraud Activity Analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76757648?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Supply Network Planning Expert (Maternity Leave Cover)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76591631?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Руководитель Департамента аналитики в Практикум',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76009346?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Project Manager (Команда аналитики)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/75630898?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Аналитик в команду продаж',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/75891914?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'FP&A Manager (Logistics costs)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/70588457?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'System Analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76993453?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Product manager',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77090848?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Marketing analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76941208?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Продуктовый аналитик со знанием web-аналитики',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76894737?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Финансовый аналитик',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/70701008?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Team Lead Fraud Analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76923109?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'DATA-аналитик',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/75646394?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Аналитик-разработчик в команду операционной эффективности '
#                   'Лавки',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/68280983?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Продуктовый аналитик в Финтех',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76924476?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Senior продуктовый аналитик в команду отелей сервиса '
#                   'путешествий',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/75888678?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Consultant (Treasury Consulting), Digital CFO',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76826977?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Senior Data Analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77106885?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Аналитик/Менеджер проектов в отдел исследований',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': 220000,
#   'min_salary': 150000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/75824923?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Founders Associate (SaaS, Ecommerce, B2B)',
#   'vacancy_salary': '150\u202f000 – 220\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76591632?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Руководитель Департамента аналитики в Практикум',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76947142?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Финансовый контролер',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': 230000,
#   'min_salary': 230000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/75832792?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Аналитик Power BI/ ETL- разработчик',
#   'vacancy_salary': '230\u202f000 – 230\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/71494399?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Бизнес-аналитик в отдел управленческой отчетности '
#                   '(Финансовый департамент)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77092733?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'System Analyst (Payment Gateway)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77073864?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Executive 1-3, Transaction Services / Deal Advisory '
#                   'Department (Almaty/Astana)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/66173456?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'QA Functional Engineer (Intern)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/71214153?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Бизнес-аналитик (по разработке ПО)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/72544715?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Системный аналитик / system analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76765711?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Insights & Analytics Specialist',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76329047?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Аналитик в доставку Маркета',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76996033?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Intern (Business Valuation, Deal Advisory)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76959800?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Andersen Trainee',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/75904620?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'QA Intern - Functional testing',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76656276?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Эксперт методолог (RBA, RСM, RBI)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76959941?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Andersen Trainee',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76867453?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Project/Product manager',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/48411370?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'АККРЕДИТОВАННАЯ КОМПАНИЯ Data Scientist / Python '
#                   'разработчик',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76804176?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Lead Business Analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76979238?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Системный/Бизнес - аналитик',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/72939310?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Investment analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77087362?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Product Manager',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'USD',
#   'max_salary': None,
#   'min_salary': 3000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76243038?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Web 3 Venture Associate',
#   'vacancy_salary': 'от 3\u202f000 USD',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76979036?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Senior Product Analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76049575?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Analyst Gross-To-Net',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76867518?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Tax Specialist (C1)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76867504?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Project/product manager',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76525938?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Manager (Business Valuation, Modelling, Economics)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'USD',
#   'max_salary': None,
#   'min_salary': 2000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76821229?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Product Analyst (Remote)',
#   'vacancy_salary': 'от 2\u202f000 USD',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/75679210?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Менеджер по качеству данных/Data Quality Specialist',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76847367?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Аналитик данных/Data analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76437336?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'FP&A Commercial Efficiency Analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76585948?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Brand Manager',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76031197?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Product Manager FinTech',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'KZT',
#   'max_salary': 600000,
#   'min_salary': 500000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76596165?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Marketing manager',
#   'vacancy_salary': '500\u202f000 – 600\u202f000 KZT',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/73992936?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Business Analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76383211?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Инженер данных (Frontend)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/73762644?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Brand Manager',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76960085?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Andersen Trainee',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/75889655?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Специалист по BigData',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/75680165?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Data Analyst/Marketing analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/75643603?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Category manager',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/72182503?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Intern to Business Valuation (Astana)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/75785601?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Intern Deal Advisory',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76704610?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Business Analyst // Relocation',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/72759089?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Marketing analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/75747065?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Senior / Investment Analyst, Private Equity Fund',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76444381?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Lead Performance Marketing',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/73372498?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Market Analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76819131?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Cash Product Manager (Almaty, Kazakhstan)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76659362?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Старший аналитик',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76507412?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Media Insights analyst / Специалист по анализу данных о '
#                   'потребителе в медиа',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/72414326?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Продуктовый аналитик (Retail Project Office)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76636257?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Finance Controller',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76854187?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Marketing Manager (FMCG)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': None,
#   'min_salary': 30000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76719394?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Junior SEO Specialist with knowledge of English',
#   'vacancy_salary': 'от 30\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76870591?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Продуктовый аналитик',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': 150000,
#   'min_salary': 60000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76303615?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Маркетолог-аналитик',
#   'vacancy_salary': '60\u202f000 – 150\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/73351004?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Business Analyst (mobile development)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/74811339?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'PPC manager',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76515823?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Lead Data Quality Analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76712217?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Продуктовый аналитик',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': 300000,
#   'min_salary': 250000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76410864?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Финансовый аналитик',
#   'vacancy_salary': '250\u202f000 – 300\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76817636?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Budget and Cost Control Manager',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': 150000,
#   'min_salary': 75000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76418611?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Аналитик/BI аналитик (Tableau)',
#   'vacancy_salary': '75\u202f000 – 150\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76536042?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'BI analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': None,
#   'min_salary': 70000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76681245?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Бизнес-аналитик',
#   'vacancy_salary': 'от 70\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76564432?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Аналитик данных',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'USD',
#   'max_salary': 2000,
#   'min_salary': 1500,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76688088?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'International Supply Chain Solution Manager',
#   'vacancy_salary': '1\u202f500 – 2\u202f000 USD',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/71909816?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Продуктовый аналитик (B2B RTE)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76385534?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Data Analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76751823?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Аналитик (менеджер по сегментации)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76676256?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Ведущий продуктовый аналитик',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': 130000,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76148260?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Sales Analyst (Infinix)',
#   'vacancy_salary': 'до 130\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76536040?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'BI analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76608440?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Bioinformatician - Kassandra (Yerevan)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76608441?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Bioinformatician - Kassandra (Yerevan)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76786635?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Brand Manager (Demix Performance)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76739863?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Руководитель аналитики (Почта)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/73120643?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Junior Category Manager (Laundry & Home Care)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/75629410?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'BI & Consumer Insights Manager',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': 290000,
#   'min_salary': 150000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/73500441?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Data Analyst (Middle/Senior)',
#   'vacancy_salary': '150\u202f000 – 290\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76239391?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Purchasing & Investment Controller / Analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'EUR',
#   'max_salary': 3500,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76564591?from=vacancy_search_list&query=analysis',
# ...
#   'max_salary': 2000,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76039686?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Content Manager',
#   'vacancy_salary': 'до 2\u202f000 USD',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76042809?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Senior/regular QA auto (C++ OR Java OR Python)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76202812?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Technical Administrator',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'USD',
#   'max_salary': 700,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76039849?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Personal assistant manager',
#   'vacancy_salary': 'до 700 USD',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/74192605?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Tech Lead GoLang',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': None,
#   'min_salary': 160000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76010859?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Senior Python Developer',
#   'vacancy_salary': 'от 160\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76001437?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Lead Generation Specialist',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/75993602?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Lead E-Commerce Developer',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/73807602?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Technical Expert Biologicals / Технический эксперт '
#                   'направления биологические решения',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'USD',
#   'max_salary': 5000,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76005702?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Backend/Fullstack Software Engineer (fintech, remote)',
#   'vacancy_salary': 'до 5\u202f000 USD',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/75968903?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Database administrator',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76256172?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Personal Assistant',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': 60000,
#   'min_salary': 30000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76012324?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Менеджер по работе на wildberries',
#   'vacancy_salary': '30\u202f000 – 60\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/75990844?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'QA Automation iOS (to Cyprus)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': None,
#   'min_salary': 34000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/75943860?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Project manager',
#   'vacancy_salary': 'от 34\u202f000 руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'USD',
#   'max_salary': 1500,
#   'min_salary': 1400,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/75957921?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Executive Assistant of the CEO / Помощник генерального '
#                   'директора',
#   'vacancy_salary': '1\u202f400 – 1\u202f500 USD',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'KZT',
#   'max_salary': 450000,
#   'min_salary': 250000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76893194?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Закупщик',
#   'vacancy_salary': '250\u202f000 – 450\u202f000 KZT',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'руб.',
#   'max_salary': 6000,
#   'min_salary': 2500,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76783492?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Media Buyer',
#   'vacancy_salary': '2\u202f500 – 6\u202f000 бел.\xa0руб.',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76790629?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Аналитик-маркетолог для управления маркетплейсами',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76914222?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Accountant',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76807326?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Marketing Assistant',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76845496?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Junior Sales Manager / Business Development Manager (Lead '
#                   'Generation)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'USD',
#   'max_salary': 800,
#   'min_salary': 500,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76912233?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Персональный ассистент PA / Project Manager',
#   'vacancy_salary': '500 – 800 USD',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'сум',
#   'max_salary': None,
#   'min_salary': 30000000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/75840798?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Audit Senior',
#   'vacancy_salary': 'от 30\u202f000\u202f000 сум',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'USD',
#   'max_salary': None,
#   'min_salary': 1200,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76763421?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Lead Generation Manager (AR/3D)',
#   'vacancy_salary': 'от 1\u202f200 USD',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76600163?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Product manager/Brand manager',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'KZT',
#   'max_salary': 560000,
#   'min_salary': 450000,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76032047?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Старший эксперт по аудиту',
#   'vacancy_salary': '450\u202f000 – 560\u202f000 KZT',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76838660?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Lawyer (Data Privacy), Office of General Counsel',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76531848?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Sales Manager (Smartphones Business)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76480658?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Sales Manager',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/74157991?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Product Manager',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76620416?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Customer Service Executive',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76594127?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Regional Compensation and Benefits Lead, Europe & Middle '
#                   'East',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76539473?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Utility Institutional Manager (Team Leader)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76675430?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'IT Manager',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76407454?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Marketing manager',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77079685?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Аналитик данных',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/71867753?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'SEO Specialist',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/75641735?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Team Lead Fraud Analyst',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76769866?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'System analyst (remote)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76903127?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Lean 6 Sigma Manager for Project AGPZ (Svobodniy)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76967856?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Сhief Product Officer (CPO)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'EUR',
#   'max_salary': 1800,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77029375?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Middle & Back Office Manager (remotely position)',
#   'vacancy_salary': 'до 1\u202f800 EUR',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'EUR',
#   'max_salary': 1800,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77029383?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Middle & Back Office Manager (remote)',
#   'vacancy_salary': 'до 1\u202f800 EUR',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'EUR',
#   'max_salary': 1800,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77029377?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Middle & Back Office Manager (remote)',
#   'vacancy_salary': 'до 1\u202f800 EUR',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'EUR',
#   'max_salary': 1800,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77029381?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Middle & Back Office Manager',
#   'vacancy_salary': 'до 1\u202f800 EUR',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'EUR',
#   'max_salary': 1800,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77029378?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Middle & Back Office Manager (remote)',
#   'vacancy_salary': 'до 1\u202f800 EUR',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'EUR',
#   'max_salary': 1800,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77029379?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Middle & Back Office Manager (remote)',
#   'vacancy_salary': 'до 1\u202f800 EUR',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76327423?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Data Engineer (Томск)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76327290?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Data Engineer',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76213320?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Аналитик по интеграции данных (Разработчик SQL)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'USD',
#   'max_salary': 3800,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76289206?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Data Steward Intern',
#   'vacancy_salary': 'до 3\u202f800 USD',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': 'EUR',
#   'max_salary': 1800,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77029376?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Middle & Back Office Manager (remote)',
#   'vacancy_salary': 'до 1\u202f800 EUR',
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/77074801?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Senior RTOS Engineer (to Armenia / Portugal)',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76977274?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Инженер по сметам',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'},
#  {'currency_salary': None,
#   'max_salary': None,
#   'min_salary': None,
#   'vacancy_link': 'https://tomsk.hh.ru/vacancy/76977275?from=vacancy_search_list&query=analysis',
#   'vacancy_name': 'Инженер по сметам',
#   'vacancy_salary': None,
#   'vacancy_source': 'hh.ru'}]
